# %% [markdown]
# ## PDF RAG
#
# 1. Prompt
# 2. Output Parsers
# 3. Model
# 4. Memory
# 5. PDF Document Loader
# 6. Text Splitter
# 7. Embedding
# 8. Vector DB
# 9. Retriever
#
# - 위 구성요소를 기반으로 어떤 LCEL(LangChain Expression Language)을 구축?
# - Evaluations은 어떻게 할 건가?

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True
